# %%
import pandas as pd
from datetime import datetime
from datetime import timedelta
from api_utils import request_forecast,init_settings

start_date,end_date = init_settings()

# %%
df_list = []
start = datetime.strptime(start_date, '%Y-%m-%d').date()
end = datetime.strptime(end_date, '%Y-%m-%d').date()


while (start<=end):
    row = request_forecast(start)
    df_list.append(row)
    start = start + timedelta(days=1)

df = pd.concat(df_list)

# %%
df.head()
# Out:
#          date    lat   long    country          city  mintemp_c  maxtemp_c  \
# 0  2023-04-01 -34.59 -58.67  Argentina  Buenos Aires       11.3       23.8
# 0  2023-04-02 -34.59 -58.67  Argentina  Buenos Aires       14.6       28.1
# 0  2023-04-03 -34.59 -58.67  Argentina  Buenos Aires       15.2       19.9
# 0  2023-04-04 -34.59 -58.67  Argentina  Buenos Aires       14.9       24.8
# 0  2023-04-05 -34.59 -58.67  Argentina  Buenos Aires       17.6       24.7
#
#    avgtemp_c  avghumidity  totalprecip_mm           description
# 0       17.0         54.0             0.0         Partly cloudy
# 0       20.8         53.0             0.0         Partly cloudy
# 0       17.6         88.0            26.0     Light rain shower
# 0       19.1         78.0             0.0                   Fog
# 0       20.5         71.0             0.1  Patchy rain possible

# %%
df.to_csv(f'data/01_raw/{start_date}_{end_date}.csv',index=False)
